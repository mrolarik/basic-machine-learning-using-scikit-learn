# %% [markdown]
# # Seaborn Library

# %% [markdown]
# การติดตั้งไลบรารี่ __seaborn__ ทำได้โดย
# ```
# $ pip install seaborn
# ```
#
# หากจะติดตั้ผ่าน Jupyter Notebook สามารถทำได้โดย
# ```
# $ ! pip install seaborn
# ```
#
# ไลบรารี่ Seaborn จะทำงานควบคู่กับไลบรารี่ __Pandas__ ดังนั้น หากยังไม่ได้ติดตั้ง Pandas สามารถทำได้โดย
# ```
# $ pip install pandas
# ```
#
# หรือติดตั้งผ่าน Jupyter Notebook
# ```
# $ ! pip install pandas
# ```

# %%
# ติดตั้ง seaborn ผ่าน Jupyter Notebook

! pip install seaborn
# Out:
# ...
# You are using pip version 9.0.1, however version 10.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# ทดสอบการอิมพอร์ต seaborn
import seaborn as sns

# %%
# ทดสอบการเรียก Iris dataset จาก seaborn library

import seaborn as sns 
iris_dataset = sns.load_dataset('iris')
iris_dataset.head()

# dataset ที่โหลดมาจะอยู่ในรูปแบบของ Pandas DataFrame
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ## Visualization of the Iris dataset

# %%
import seaborn as sns
sns.set()
sns.pairplot(iris_dataset, hue='species', size=2.5)

# %% [markdown]
# การทำงานร่วมกับ Scikit-Learn เราจะต้องทำการดึงข้อมูล (extract) อาเรย์ feature และ target ออกมาจาก DataFrame

# %%
X_iris = iris_dataset.drop('species', axis=1)
X_iris.shape
# Out:
# (150, 4)

# %%
y_iris = iris_dataset['species']
y_iris.shape
# Out:
# (150,)

# %%
# type of variable
type(X_iris)
# Out:
# pandas.core.frame.DataFrame

# %%
# print first 5 rows
X_iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
X_iris.head(3)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2

# %% [markdown]
# ## Select row by integer position

# %%
# ดูข้อมูล row ที่ i
X_iris.iloc[1]  # row 1
# Out:
# sepal_length    4.9
# sepal_width     3.0
# petal_length    1.4
# petal_width     0.2
# Name: 1, dtype: float64

# %%
X_iris.iloc[0]  # row 0
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
X_iris.iloc[0,0]  # row 0, col 0
# Out:
# 5.1

# %%
X_iris.iloc[0,1]  # row 0, col 1
# Out:
# 3.5

# %%
X_iris.iloc[:,1] # row all, col 1
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
# 5      3.9
# 6      3.4
# 7      3.4
# 8      2.9
# 9      3.1
# 10     3.7
# 11     3.4
# 12     3.0
# 13     3.0
# 14     4.0
# 15     4.4
# 16     3.9
# 17     3.5
# 18     3.8
# 19     3.8
# 20     3.4
# 21     3.7
# 22     3.6
# 23     3.3
# 24     3.4
# 25     3.0
# 26     3.4
# 27     3.5
# 28     3.4
# 29     3.2
#       ...
# 120    3.2
# 121    2.8
# 122    2.8
# 123    2.7
# 124    3.3
# 125    3.2
# 126    2.8
# 127    3.0
# 128    2.8
# 129    3.0
# 130    2.8
# 131    3.8
# 132    2.8
# 133    2.8
# 134    2.6
# 135    3.0
# 136    3.4
# 137    3.1
# 138    3.0
# 139    3.1
# 140    3.1
# 141    3.1
# 142    2.7
# 143    3.2
# 144    3.3
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_width, dtype: float64

# %%
X_iris.iloc[0:5,1] # row 0 to 5, col 1
# Out:
# 0    3.5
# 1    3.0
# 2    3.2
# 3    3.1
# 4    3.6
# Name: sepal_width, dtype: float64

# %%
X_iris.iloc[0:5,:] # row 0 to 5, col all
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
X_iris.iloc[0:5,0:3] # row 0 t0 5, col 0 to 3
# Out:
#    sepal_length  sepal_width  petal_length
# 0           5.1          3.5           1.4
# 1           4.9          3.0           1.4
# 2           4.7          3.2           1.3
# 3           4.6          3.1           1.5
# 4           5.0          3.6           1.4

# %%
X_iris[0:3]  # X_iris[row]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
