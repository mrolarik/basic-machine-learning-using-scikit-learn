# %% [markdown]
# # Linear Regression: Housing dataset

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
from sklearn.cross_validation import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
from sklearn.datasets import load_boston  # housing dataset
boston = load_boston()

# %%
print(boston.keys())
# Out:
# ['data', 'feature_names', 'DESCR', 'target']

# %%
print(boston.DESCR)  #print(boston['DESCR'])
# Out:
# Boston House Prices dataset
# ...
#
# Notes
# ------
# Data Set Characteristics:
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive
#
#     :Median Value (attribute 14) is usually the target
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
#         - TAX      full-value property-tax rate per $10,000
# ...

# %%
print("shape of the data", boston.data.shape)  
#print("shape of the data", boston['data'].shape)
boston['data'][:2,:] # row = 2, col = all
# Out:
# ('shape of the data', (506, 13))
# array([[  6.32000000e-03,   1.80000000e+01,   2.31000000e+00,
#           0.00000000e+00,   5.38000000e-01,   6.57500000e+00,
#           6.52000000e+01,   4.09000000e+00,   1.00000000e+00,
#           2.96000000e+02,   1.53000000e+01,   3.96900000e+02,
#           4.98000000e+00],
#        [  2.73100000e-02,   0.00000000e+00,   7.07000000e+00,
#           0.00000000e+00,   4.69000000e-01,   6.42100000e+00,
#           7.89000000e+01,   4.96710000e+00,   2.00000000e+00,
#           2.42000000e+02,   1.78000000e+01,   3.96900000e+02,
#           9.14000000e+00]])

# %%
boston['target'][:2]
# Out:
# array([ 24. ,  21.6])

# %%
print("shape of the target", boston['target'].shape)
boston['target'][:10]
# Out:
# ('shape of the target', (506,))
# array([ 24. ,  21.6,  34.7,  33.4,  36.2,  28.7,  22.9,  27.1,  16.5,  18.9])

# %%
print(boston.keys())
# Out:
# ['data', 'feature_names', 'DESCR', 'target']

# %%
# import dataset into pandas DataFrame
df_x = pd.DataFrame(boston.data, columns=boston.feature_names)
df_y = pd.DataFrame(boston.target)

# %%
# show the DataFrame
df_x.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.593761   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.596783   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.647423   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
df_y.describe()
# Out:
#                 0
# count  506.000000
# mean    22.532806
# std      9.197104
# min      5.000000
# 25%     17.025000
# 50%     21.200000
# 75%     25.000000
# max     50.000000

# %% [markdown]
# # Create Linear regression

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
from sklearn.cross_validation import train_test_split
from sklearn.datasets import load_boston  # housing dataset

boston = load_boston()

# %% [markdown]
# ## Use only one feature, select column 5 = RM

# %%
# select column 5 = RM
y = boston['target']
X = boston['data']
x_train, x_test, y_train, y_test = train_test_split(X[:,5], y, test_size=0.2, random_state=4)

# create a model
reg.fit(x_train.reshape(-1, 1), y_train.reshape(-1, 1))

# prediction
y_pred = reg.predict(x_test.reshape(-1, 1))

# %%
# Plot outputs
rng = np.random.RandomState(42)
colors = rng.rand(x_test.shape[0])
sizes = 800 * rng.rand(x_test.shape[0])

plt.figure(figsize=(10,8))
plt.scatter(x_test, y_test,  c=colors, s=sizes)
plt.plot(x_test, y_pred, '--r')

plt.xticks(())
plt.yticks(())

plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 8))
plt.plot(y_test, linewidth=1, linestyle='solid', color='blue', label='Observed data')
plt.plot(y_pred, '--r', linewidth=2, label='Predicted output')
plt.legend(frameon=True, loc='upper left')

plt.show()

# %%
# The coefficients
print('Coefficients: \n', reg.coef_)
# The mean squared error
print("Mean squared error: %.2f"
      % mean_squared_error(y_test, y_pred))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(y_test, y_pred))
# Out:
# ('Coefficients: \n', array([[ -1.14743504e-01,   4.70875035e-02,   8.70282354e-03,
#           3.23818824e+00,  -1.67240567e+01,   3.87662996e+00,
#          -1.08218769e-02,  -1.54144627e+00,   2.92604151e-01,
#          -1.33989537e-02,  -9.07306805e-01,   8.91271054e-03,
#          -4.58747039e-01]]))
# Mean squared error: 25.41
# Variance score: 0.73

# %% [markdown]
# ## select column 2 = INDUS

# %%
y = boston['target']
X = boston['data']
x_train, x_test, y_train, y_test = train_test_split(X[:,2], y, test_size=0.2, random_state=4)

# create a model
reg.fit(x_train.reshape(-1, 1), y_train.reshape(-1, 1))

# prediction
y_pred = reg.predict(x_test.reshape(-1, 1))

# %%
# Plot outputs
rng = np.random.RandomState(42)
colors = rng.rand(x_test.shape[0])
sizes = 800 * rng.rand(x_test.shape[0])

plt.figure(figsize=(10,8))
plt.scatter(x_test, y_test,  c=colors, s=sizes)
plt.plot(x_test, y_pred, '--r')

plt.xticks(())
plt.yticks(())

plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 8))
plt.plot(y_test, linewidth=1, linestyle='solid', color='blue', label='Observed data')
plt.plot(y_pred, '--r', linewidth=2, label='Predicted output')
plt.legend(frameon=True, loc='upper left')

plt.show()

# %%
# The coefficients
print('Coefficients: \n', reg.coef_)
# The mean squared error
print("Mean squared error: %.2f"
      % mean_squared_error(y_test, y_pred))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(y_test, y_pred))
# Out:
# ('Coefficients: \n', array([[-0.65143285]]))
# Mean squared error: 75.47
# Variance score: 0.19

# %% [markdown]
# ## Example

# %%
reg = linear_model.LinearRegression()

# %%
print("size of df_x", df_x.shape)
print

# split train test data
x_train, x_test, y_train, y_test = train_test_split(df_x, df_y, test_size=0.2, random_state=4)

print("size of x_train", x_train.shape)
print("size of x_test", x_test.shape)
print

print("size of y_train", y_train.size)
print("size of y_test", y_test.size)
# Out:
# ('size of df_x', (506, 13))
#
# ('size of x_train', (404, 13))
# ('size of x_test', (102, 13))
#
# ('size of y_train', 404)
# ('size of y_test', 102)

# %%
# create a model
reg.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
reg.coef_
# Out:
# array([[ -1.14743504e-01,   4.70875035e-02,   8.70282354e-03,
#           3.23818824e+00,  -1.67240567e+01,   3.87662996e+00,
#          -1.08218769e-02,  -1.54144627e+00,   2.92604151e-01,
#          -1.33989537e-02,  -9.07306805e-01,   8.91271054e-03,
#          -4.58747039e-01]])

# %%
# prediction
y_pred = reg.predict(x_test)

# %%
print("size of y_predict", y_pred.shape)
# Out:
# ('size of y_predict', (102, 1))

# %%
y_pred[:10]
# Out:
# array([[ 12.06508881],
#        [ 26.98544801],
#        [ 17.59242607],
#        [ 18.15842166],
#        [ 36.91656975],
#        [ 25.43573299],
#        [ 31.08610267],
#        [ 19.7198111 ],
#        [ 19.63707329],
#        [ 22.95805783]])

# %%
y_test[:10]
# Out:
#         0
# 8    16.5
# 289  24.8
# 68   17.4
# 211  19.3
# 226  37.6
# 70   24.2
# 55   35.4
# 470  19.9
# 409  27.5
# 154  17.0

# %%
# mean square error (MSE)

np.mean((y_test - y_pred)**2)
# Out:
# 0    25.407977
# dtype: float64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,8))
plt.plot(y_test[0].as_matrix(), linewidth=1, linestyle='solid', color='blue', label='Observed data')
plt.plot(y_pred.T[:][0], '--r', linewidth=2, label='Predicted output')
plt.legend(frameon=True, loc='upper left')

plt.show()

# %%
# The coefficients
print('Coefficients: \n', reg.coef_)
# The mean squared error
print("Mean squared error: %.2f"
      % mean_squared_error(y_test, y_pred))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(y_test, y_pred))
# Out:
# ('Coefficients: \n', array([[ -1.14743504e-01,   4.70875035e-02,   8.70282354e-03,
#           3.23818824e+00,  -1.67240567e+01,   3.87662996e+00,
#          -1.08218769e-02,  -1.54144627e+00,   2.92604151e-01,
#          -1.33989537e-02,  -9.07306805e-01,   8.91271054e-03,
#          -4.58747039e-01]]))
# Mean squared error: 25.41
# Variance score: 0.73
