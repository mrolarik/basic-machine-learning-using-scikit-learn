# %% [markdown]
# # K-Means Clustering
#
# ![alt text](https://cdn-images-1.medium.com/max/638/0*rrzG3LyOnAvOepbJ.png "K-Means Clustering")
#
# อัลกอริธึม K-Means เป็นวิธีที่ใช้ค้นหาจำนวนของคลัสเตอร์ (Cluster) จากข้อมูลที่ไม่มีคลาส (Class) หรือไม่มี Label (Unlabeled) วิธีนี้จึงเป็น Unsupervised Learning หรือ Clustering

# %% [markdown]
# ## create sample data

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.datasets.samples_generator import make_blobs

rng = np.random.RandomState(0)
colors = rng.rand(300)

X, y_true = make_blobs(n_samples=300, centers=4,
                       cluster_std=0.85, random_state=2)

plt.style.use('seaborn-darkgrid')
plt.figure(figsize=(10,7))
plt.scatter(X[:, 0], X[:, 1], s=200, alpha=0.4, cmap='viridis');
plt.show()

# %% [markdown]
# ## create K-Means Model

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=4)
kmeans.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=4, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %% [markdown]
# # prediction

# %%
y_kmeans = kmeans.predict(X)

# %%
print("output", y_kmeans[0:20])
# Out:
# ('output', array([0, 0, 1, 0, 3, 2, 0, 2, 1, 0, 3, 0, 0, 2, 2, 3, 1, 2, 3, 0],
#       dtype=int32))

# %%
plt.figure(figsize=(10,7))

# plot group of data
plt.scatter(X[:, 0], X[:, 1], c=y_kmeans, s=250, alpha=0.5, cmap='viridis')
centers = kmeans.cluster_centers_

# plot cluster/centroid
#plt.scatter(centers[:, 0], centers[:, 1], c='blue', s=300, alpha=0.7)
plt.scatter(centers[0, 0], centers[0, 1], c='blue', s=300, alpha=0.7, label='centroid 1')
plt.scatter(centers[1, 0], centers[1, 1], c='black', s=300, alpha=0.7, label='centroid 2')
plt.scatter(centers[2, 0], centers[2, 1], c='red', s=300, alpha=0.7, label='centroid 3')
plt.scatter(centers[3, 0], centers[3, 1], c='gray', s=300, alpha=0.7, label='centroid 4')

plt.legend(frameon=True, loc='lower left')
plt.show()

# %% [markdown]
# # create new data points

# %%
X_test, y_test_true = make_blobs(n_samples=10, centers=4, 
                                 cluster_std=0.85, random_state=2)

# %%
X_test.shape
# Out:
# (10, 2)

# %% [markdown]
# # Visualize new data points

# %%
plt.figure(figsize=(10,7))

# plot group of data
plt.scatter(X[:, 0], X[:, 1], c=y_kmeans, s=250, alpha=0.5, cmap='viridis')
centers = kmeans.cluster_centers_

# plot cluster/centroid
#plt.scatter(centers[:, 0], centers[:, 1], c='blue', s=300, alpha=0.8, label='centroids')
plt.scatter(centers[0, 0], centers[0, 1], c='blue', s=300, alpha=0.7, label='centroid 1')
plt.scatter(centers[1, 0], centers[1, 1], c='black', s=300, alpha=0.7, label='centroid 2')
plt.scatter(centers[2, 0], centers[2, 1], c='red', s=300, alpha=0.7, label='centroid 3')
plt.scatter(centers[3, 0], centers[3, 1], c='gray', s=300, alpha=0.7, label='centroid 4')

# plot new data point
plt.scatter(X_test[:, 0], X_test[:, 1], c='white', s=350, alpha=1, label='new data point')
plt.legend(frameon=True, loc='lower left')

plt.show()

# %% [markdown]
# ## Predict new data points

# %%
y_test_kmeans = kmeans.predict(X_test)

# %%
y_test_kmeans
# Out:
# array([1, 3, 1, 3, 2, 2, 0, 3, 2, 0], dtype=int32)

# %%
plt.figure(figsize=(10,7))

# plot group of data
plt.scatter(X[:, 0], X[:, 1], c=y_kmeans, s=250, alpha=0.5, cmap='viridis')
centers = kmeans.cluster_centers_

# plot cluster/centroid
plt.scatter(centers[:, 0], centers[:, 1], c='blue', s=300, alpha=0.8, label='centroids')

# plot new data point
plt.scatter(X_test[:, 0], X_test[:, 1], c=y_test_kmeans, s=350, alpha=0.7)
plt.legend(frameon=True, loc='lower left')

plt.show()
